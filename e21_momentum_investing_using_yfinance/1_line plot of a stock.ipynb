# %%
import pandas as pd
import dateutil

# %%
df = pd.read_csv('data/individual stocks/TATASTEEL.NS.csv')

# %%
df['Date'] = df['Date'].apply(lambda x: dateutil.parser.parse(x))

# %%
df.sort_values(by="Date", inplace = True)

# %%
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2021-06-01  112.000000  112.300003  108.550003  110.089996   46.352627
# 1   2021-06-02  110.500000  112.980003  110.400002  112.404999   47.327343
# 2   2021-06-03  112.955002  113.974998  111.300003  112.199997   47.241028
# 3   2021-06-04  111.599998  112.879997  110.699997  112.070000   47.186298
# 4   2021-06-07  113.000000  115.000000  112.555000  112.870003   47.523132
# ..         ...         ...         ...         ...         ...         ...
# 493 2023-05-26  105.000000  106.750000  104.949997  106.400002  103.037048
# 494 2023-05-29  107.000000  108.849998  106.300003  108.449997  105.022255
# 495 2023-05-30  108.949997  108.949997  106.900002  107.050003  103.666512
# 496 2023-05-31  106.400002  106.949997  105.599998  105.800003  102.456017
# 497 2023-06-01  105.900002  106.699997  105.800003  105.949997  102.601273
#
#         Volume
# 0    176909250
# 1    128625910
# 2    121094770
# 3     97133470
# 4    122185920
# ..         ...
# 493   28362042
# 494   41062311
# 495   33475211
# 496   41249944
# 497   21211538
#
# [498 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(df['Date'], df['Close'])
plt.show()
