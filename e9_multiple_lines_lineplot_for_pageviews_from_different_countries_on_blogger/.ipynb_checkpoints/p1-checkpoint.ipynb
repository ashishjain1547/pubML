# %%
import pandas as pd

# %%
df_uganda = pd.read_excel('20220927.xlsx', sheet_name = 'Uganda')
df_brazil = pd.read_excel('20220927.xlsx', sheet_name = 'Brazil')
df_canada = pd.read_excel('20220927.xlsx', sheet_name = 'Canada')
df_uk = pd.read_excel('20220927.xlsx', sheet_name = 'UK')
df_kenya = pd.read_excel('20220927.xlsx', sheet_name = 'Kenya')
df_uae = pd.read_excel('20220927.xlsx', sheet_name = 'UAE')
df_germany = pd.read_excel('20220927.xlsx', sheet_name = 'Germany')
df_russia = pd.read_excel('20220927.xlsx', sheet_name = 'Russia')
df_us = pd.read_excel('20220927.xlsx', sheet_name = 'US')
df_india = pd.read_excel('20220927.xlsx', sheet_name = 'India')
df_global = pd.read_excel('20220927.xlsx', sheet_name = 'Global')

# %%
df = df_uganda.merge(df_brazil, on = 'Timestamp', how = 'inner')
df = df.merge(df_canada, on = 'Timestamp', how = 'inner')
df = df.merge(df_uk, on = 'Timestamp', how = 'inner')
df = df.merge(df_kenya, on = 'Timestamp', how = 'inner')
df = df.merge(df_uae, on = 'Timestamp', how = 'inner')
df = df.merge(df_germany, on = 'Timestamp', how = 'inner')
df = df.merge(df_russia, on = 'Timestamp', how = 'inner')
df = df.merge(df_us, on = 'Timestamp', how = 'inner')
df = df.merge(df_india, on = 'Timestamp', how = 'inner')
df = df.merge(df_global, on = 'Timestamp', how = 'inner')

# %%
df
# Out:
#         Timestamp  Current Views in Uganda  Current Views in Brazil  \
# 0   20220601 2212                     2586                     3454
# 1   20220602 1214                     2602                     3445
# 2   20220603 0730                     2629                     3476
# 3   20220604 2108                     2629                     3471
# 4   20220605 0940                     2629                     3493
# 5   20220606 0850                     2629                     3416
# 6   20220607 0907                     2636                     3416
# 7   20220608 1309                     2636                     3413
# 8   20220609 0930                     2639                     3413
# 9   20220610 0130                     2642                     3413
# 10  20220610 0935                     2642                     3416
# 11  20220611 1132                     2639                     3416
# 12  20220612 1101                     2641                     3397
# 13  20220613 0920                     2649                     3397
# 14  20220614 1045                     2646                     3397
# 15  20220615 1620                     2646                     3397
# 16  20220616 1700                     2652                     3398
# 17  20220617 1830                     2661                     3398
# 18  20220618 1220                     2661                     3549
# 19  20220620 1345                     2683                     3407
# 20  20220621 2220                     2686                     3415
# 21  20220622 2350                     2691                     3414
# 22  20220624 0010                     2691                     3412
# 23  20220627 2150                     2702                     3609
# 24  20220629 1145                     2702                     3628
# 25  20220705 0005                     2777                     3633
# 26  20220712 0030                     2792                     3639
# 27  20220717 2000                     2798                     3654
# 28  20220724 2250                     2841                     3679
# 29  20220803 0100                     2862                     3671
# 30  20220814 2240                     2814                     3653
# 31  20220816 1717                     2847                     3670
# 32  20220820 0852                     2875                     3683
# 33  20220825 0555                     2871                     3683
# 34  20220913 1130                     2787                     3684
# 35  20220918 1521                     2787                     3681
# 36  20220923 2150                     2787                     3688
# 37  20220927 1030                     2789                     3701
# 15               163822                  780940
# 16               163883                  781190
# 17               163945                  781372
# 18               163974                  781526
# 19               164148                  781934
# 20               164211                  782612
# 21               164241                  782873
# 22               164262                  783280
# 23               164509                  784590
# 24               164714                  785446
# 25               165032                  789209
# 26               165598                  792710
# 27               166007                  794904
# 28               166340                  799083
# 29               166646                  802144
# 30               167191                  804891
# 31               167264                  805282
# 32               167470                  806333
# 33               167744                  807431
# 34               168669                  814411
# 35               168902                  815973
# 36               169117                  818839
# 37               169423                  819722
#
#     Current Views Around The World
# 0                          1200701
# 1                          1201119
# 2                          1201832
# 3                          1203274
# 4                          1203746
# 5                          1204446
# 6                          1205370
# 7                          1206064
# 8                          1206542
# 9                          1207617
# 10                         1207702
# 11                         1208191
# 12                         1208614
# 13                         1209672
# 14                         1210597
# 15                         1211169
# 16                         1211705
# 17                         1212183
# 18                         1212457
# 19                         1213423
# 20                         1214348
# 21                         1214755
# 22                         1215365
# 23                         1217370
# 24                         1218662
# 25                         1223501
# 26                         1228936
# 27                         1232430
# 28                         1237741
# 29                         1242232
# 30                         1249298
# 31                         1249976
# 32                         1251627
# 33                         1253665
# 34                         1263404
# 35                         1265884
# 36                         1269499
# 37                         1271102

# %% [markdown]
# # Africa

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
figure(figsize=(16, 6), dpi=80)
# plot lines
plt.plot(df['Timestamp'], df['Current Views in Uganda'], label = "Uganda")
plt.plot(df['Timestamp'], df['Current Views in Kenya'], label = "Kenya")

plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.legend()
plt.show()

# %% [markdown]
# # Range 10K

# %%
figure(figsize=(16, 6), dpi=80)
# plot lines
plt.plot(df['Timestamp'], df['Current Views in UK'], label = "UK")
plt.plot(df['Timestamp'], df['Current Views in Kenya'], label = "Kenya")
plt.plot(df['Timestamp'], df['Current Views in UAE'], label = "UAE")
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.legend()
plt.show()

# %% [markdown]
# # Range 20K

# %%
figure(figsize=(16, 6), dpi=80)
# plot lines
plt.plot(df['Timestamp'], df['Current Views in Germany'], label = "Germany")
plt.plot(df['Timestamp'], df['Current Views in Russia'], label = "Russia")
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.legend()
plt.show()

# %% [markdown]
# # US

# %%
figure(figsize=(16, 6), dpi=80)
# plot lines
plt.plot(df['Timestamp'], df['Current Views in US'], label = "US")
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.legend()
plt.show()

# %% [markdown]
# # India and Global

# %%
figure(figsize=(16, 6), dpi=80)
# plot lines
plt.plot(df['Timestamp'], df['Current Views Around The World'], label = "World")
plt.plot(df['Timestamp'], df['Current Views in India'], label = "India")
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.legend()
plt.show()
