# %% [raw]
# # Windows
# !cd D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp
# !del /s /q *.pyc

# %%
# Ubuntu
# !cd soan_master/whatsapp
# !find . -name '*.pyc' -delete
# !find . -name '.ipynb_checkpoints' -delete
# find: cannot delete ‘./soan_master/whatsapp/.ipynb_checkpoints’: Directory not empty
# find: cannot delete ‘./.ipynb_checkpoints’: Directory not empty

# %%
# Runs in kernel: py_2716
from soan_master.whatsapp import helper_202004152020 as helper      # Helper to prepare the data
from soan_master.whatsapp import general     # General statistics

from soan_master.whatsapp import tf_idf      # To calculate TF-IDF 
# Dependency: pip install pillow (for PIL: Python Image Library)

# %%
from soan_master.whatsapp import soan_emoji # To analyze emoji use # Dependency: pip install emoji regex seaborn

# Error you get while trying to import the emoji.py as is. 
# ImportError: cannot import name emoji
# Solution: You need to rename it to something else like "soan_emoji.py"

# %%
from soan_master.whatsapp import topic       # Topic modelling and summarization # Dependency: pip install sklearn
# Dependency: "pip install pattern"
# "pattern3" is not same as "pattern" and "pattern" does not come for Python-3 (as of 20190717).

from soan_master.whatsapp import sentiment   # Sentiment Analysis
from soan_master.whatsapp import soan_wordcloud   # Create Word Clouds # Dependency: pip install wordcloud palettable

from soan_master.colors   import colors      # Frequent Color Visualization

# %matplotlib inline

# %% [markdown]
# ## <a name="general">2. General Statistics</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# Here you can find general data with regards to whatsapp conversations such as the number of messages and words. Keep in mind this is simply to get a general understanding of the conversations. More complex and interesting information can be found in the later chapters.

# %% [markdown]
# #### <a name="gs-data">2.1 Prepare Data</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# The data is preprocessed by loading in the raw txt file which is sent through whatsapp to your mail. The following columns are created:
# * Message_Raw
#     * The raw message for each user (including date and name of user)
# * User
#     * The user who has sent the message, if no users have sent that message
#     then it is simply removed from the dataframe
# * Message_Clean
#     * Only containing the message, but with all possible symbols in there
#     Thus, no date and no name of the user
# * Message_Only_Text
#     * Only text, lowercase
# * Date
#     * Date in the format y/m/d

# %%
#df = helper.import_data('WhatsApp Chat with FSADM Team.txt')
#df = helper.import_data('WhatsApp Chat with Cousins (201910-201912).txt')
#df = helper.import_data('files_1/WhatsApp Chat with BITS Lounge (20200117).txt')
df = helper.import_data('files_1/WhatsApp Chat with Cousins (201910-201912).txt')

# %%
df.head()
# Out:
#    index                                        Message_Raw     User
# 0      0              17/10/2019, 11:38 am - Srishti: Lol\n  Srishti
# 1      1  20/10/2019, 9:04 pm - Srishti: Anushka - pleas...  Srishti
# 2      2  20/10/2019, 9:05 pm - Srishti: Ashish Chandiga...  Srishti
# 3      3  22/10/2019, 8:45 am - Srishti: Thank you so mu...  Srishti
# 4      4       22/10/2019, 8:48 am - Srishti: Thank you!!\n  Srishti

# %%
df.tail()
# Out:
#      index                                        Message_Raw    User
# 485      2         23/10/2019, 6:15 am - Sameer: And Shruti\n  Sameer
# 486      3       27/10/2019, 8:15 pm - Sameer: Happy Diwali\n  Sameer
# 487      4  21/12/2019, 12:05 pm - Sameer: Happy belated b...  Sameer
# 488      5  21/12/2019, 12:10 pm - Sameer: exams ke time t...  Sameer
# 489      6  22/12/2019, 1:17 am - Sameer: Computer process...  Sameer

# %%
df = helper.preprocess_data(df)

# %%
df.head()

# %%
df['User'] = df.apply(lambda row: ''.join([i if ord(i) < 128 else '' for i in row.User]), axis = 1)
# Removing emoticons from name
# This LOC is not working from Python file and is hence commented there.
# File 'D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp\helper.py'

# %%
# Change labels for anonymization 
#user_labels = {old: new for old, new in zip(sorted(df.User.unique()), ['Her', 'Me'])}
#df.User = df.User.map(user_labels)

# %% [markdown]
# #### <a name="users">2.2 Users in the group</a>
# [Back to Table of Contents](#table)

# %%
#general.print_users(df)

# %% [markdown]
# #### <a name="gs-messages">2.3 Messages over time</a>
# [Back to Table of Contents](#table)

# %%
general.plot_messages(df, colors=None, trendline=False, savefig=False, dpi=100)

# %%
general.plot_messages(df[df['User'] == "Shambhavi Choudhary"], colors=None, trendline=False, savefig=False, dpi=100)

# %% [markdown]
# #### <a name="gs-active">2.4 Active Moments</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# **Daily Activity**
# This shows the daily activity per person in a spider plot and in total in a histogram.
# NOTE: This is unstandardized data, which means that it also shows the amount of messages.

# %%
general.plot_day_spider(df, colors=None, savefig=False, dpi=100)

# The spider plot is not giving the expected results.

# %%
general.plot_day_spider(df[df['User'] == 'Shambhavi Choudhary'], colors=None, savefig=False, dpi=100)

# %%
Day_of_Week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
for i in set(df.User.tolist()):
    temp = df[df.User == i].groupby('Day_of_Week').count()['index'].to_frame().reset_index()
    temp.columns = ['Day_of_Week', 'msgs_sent']
    print(i + ": " + Day_of_Week[temp[temp.msgs_sent == temp.msgs_sent.max()].iloc[0]['Day_of_Week']]
          + ": " + str(temp[temp.msgs_sent == temp.msgs_sent.max()].iloc[0]['msgs_sent']))
# Out:
# +91 96001 36104: Sunday: 8
# Sonu Sihmar Bits: Thursday: 11
# +91 94497 21155: Tuesday: 6
# +91 98409 10527: Saturday: 8
# Abdul Ahad: Tuesday: 35
# +91 91644 72637: Tuesday: 17
# Sharath Krishnan Bits: Tuesday: 112
# +91 98873 98089: Friday: 5
# Vivek Chaudhary: Tuesday: 23
# Shashi Kumar Srivastav Bits: Saturday: 49
# +1 (602) 651-8940: Wednesday: 5
# +91 98905 33682: Sunday: 18
# +91 95452 79257: Sunday: 4
# +91 98185 24648: Sunday: 5
# +91 81350 57013: Sunday: 47
# Divjot Singh: Tuesday: 650
# +91 88613 50346: Saturday: 7
# Shashi Kumar Srivastav: Tuesday: 37
# +91 89288 60704: Thursday: 28
# +91 97399 01577: Saturday: 23
# +65 9720 6217: Friday: 7
# Shambhavi Choudhary: Thursday: 39
# Dominic Gerard Bits: Friday: 42
# +91 90486 89898: Saturday: 14
# Sharath Krishnan: Tuesday: 160
# Prat Bits: Wednesday: 3
# Mayank S Kumar: Friday: 78
# +91 98402 45280: Friday: 7
# +91 90947 22757: Sunday: 5
# Rahul Singh Bits: Saturday: 22
# +91 97767 79025: Tuesday: 93
# +91 94215 80968: Sunday: 13
# +971 50 633 0314: Monday: 3
# +91 95003 10376: Sunday: 17
# Ashish Jain: Sunday: 17
# Akshay N S Bits: Tuesday: 36
# Abhishek Samuel Bits: Friday: 20
# +91 94192 45911: Saturday: 4
# +91 97654 94035: Monday: 7
# Shiva K Bits: Saturday: 6
# Akshay N S: Tuesday: 32
# +91 95608 45500: Friday: 9
# +91 87905 60139: Sunday: 24
# Salil Bansal: Tuesday: 534
# Ashutosh Bits Leisure: Saturday: 8
# +91 79046 73342: Friday: 13
# +91 98108 97330: Monday: 8
# Abhishek Samuel: Monday: 12
# Archit Gupta: Saturday: 17
# +91 78771 56879: Monday: 15
# +91 91764 00158: Sunday: 16
# Abhijit Daund Bits: Saturday: 8
# +91 95607 86617: Tuesday: 6
# +91 98453 79325: Sunday: 8
# Mayank Kumar: Friday: 31
# +91 81059 07242: Wednesday: 13
# Dominic Gerard: Tuesday: 45
# Prishkrit Abrol: Tuesday: 101
# +91 94454 54528: Thursday: 8
# +91 77608 58999: Tuesday: 8
# +91 99860 38804: Thursday: 12
# +91 97625 07666: Tuesday: 14
# +91 93227 10793: Sunday: 27
# Harmesh Rekhanshu: Tuesday: 36
# Shiva K: Tuesday: 5
# Rahul Singh: Monday: 10
# Sonu Sihmar: Saturday: 3

# %%
Day_of_Week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df[df.User == "Shambhavi Choudhary"].groupby('Day_of_Week').count()['index'].to_frame().reset_index()
# Out:
#    Day_of_Week  index
# 0            0     26
# 1            1     29
# 2            2     28
# 3            3     39
# 4            4     19
# 5            5     27
# 6            6     13

# %%
general.plot_active_days(df, savefig=False, dpi=100)

# %%
general.plot_active_days(df, savefig=False, dpi=100, user='Shambhavi Choudhary')

# %% [markdown]
# **Hourly Activity**
# It shows which days are most active based on the period in which most messages are send.

# %%
general.plot_active_hours(df, color='#121212', savefig=False, dpi=100, user='All')

# %%
general.plot_active_hours(df, color='#121212', savefig=False, dpi=100, user='Shambhavi Choudhary')

# %% [markdown]
# **Calendar Map**
# Here you can choose for which year you want to see the activity

# %%
# Need to set the index and provide a single column
general.calendar_plot(df, year=2019, how='count', column='index')

# %%
general.calendar_plot(df, year=2020, how='count', column='index')

# %% [markdown]
# #### <a name="gs-averages">2.5 Averages / Summaries</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# Here you can find general averages and summaries. For those that are interested how often a person said "I love you", you can also find that.

# %%
general.print_stats(df, love=True)
# NR / Nr / nr: implies "number"
# Out:
# ##########################
# ##  Number of Messages  ##
# ##########################
# ()
# 123	Shashi Kumar Srivastav
# 30	Rahul Singh
# 13	+91 98108 97330
# 124	Dominic Gerard
# 161	Abdul Ahad
# 174	+91 81350 57013
# 59	Ashish Jain
# 11	+91 94192 45911
# 16	+91 95607 86617
# 87	+91 91644 72637
# 10	+91 90947 22757
# 44	+91 87905 60139
# 97	Vivek Chaudhary
# 260	+91 97767 79025
# 46	+91 78771 56879
# 50	+91 91764 00158
# 34	+91 98453 79325
# 12	+91 96001 36104
# 2196	Salil Bansal
# 31	+91 97625 07666
# 13	+91 94215 80968
# 47	+91 98905 33682
# 13	+91 95452 79257
# 17	+91 77608 58999
# 469	Sharath Krishnan
# 120	Harmesh Rekhanshu
# 26	+91 95003 10376
# 240	Mayank S Kumar
# 45	+91 99860 38804
# 39	+91 89288 60704
# 8	Sonu Sihmar
# 104	Akshay N S
# 8	Shiva K
# 36	Archit Gupta
# 61	Abhishek Samuel
# 2626	Divjot Singh
# 19	+91 98402 45280
# 432	Prishkrit Abrol
# 15	+91 79046 73342
# 21	+91 97654 94035
# 15	+91 94497 21155
# 43	+91 90486 89898
# 181	Shambhavi Choudhary
# 25	Ashutosh Bits Leisure
# 16	+91 98185 24648
# 29	+91 81059 07242
# 20	+91 98409 10527
# 77	+91 93227 10793
# 21	+65 9720 6217
# 23	+91 94454 54528
# 10	+1 (602) 651-8940
# 11	+91 98873 98089
# 49	+91 97399 01577
# 11	+971 50 633 0314
# 145	Mayank Kumar
# 455	Sharath Krishnan Bits
# 7	Prat Bits
# 95	Abhishek Samuel Bits
# 158	Akshay N S Bits
# 148	Dominic Gerard Bits
# 30	Sonu Sihmar Bits
# 246	Shashi Kumar Srivastav Bits
# 14	+91 88613 50346
# 64	Rahul Singh Bits
# 17	Shiva K Bits
# 13	Abhijit Daund Bits
# 13	+91 95608 45500
# ()
# #######################
# ##  Number of Words  ##
# #######################
# ()
# 1709	Shashi Kumar Srivastav
# 227	Rahul Singh
# 55	+91 98108 97330
# 1973	Dominic Gerard
# 2838	Abdul Ahad
# 2007	+91 81350 57013
# 378	Ashish Jain
# 74	+91 94192 45911
# 49	+91 95607 86617
# 865	+91 91644 72637
# 49	+91 90947 22757
# 199	+91 87905 60139
# 1163	Vivek Chaudhary
# 2823	+91 97767 79025
# 461	+91 78771 56879
# 965	+91 91764 00158
# 192	+91 98453 79325
# 60	+91 96001 36104
# 33193	Salil Bansal
# 182	+91 97625 07666
# 46	+91 94215 80968
# 408	+91 98905 33682
# 180	+91 95452 79257
# 120	+91 77608 58999
# 3952	Sharath Krishnan
# 757	Harmesh Rekhanshu
# 192	+91 95003 10376
# 2707	Mayank S Kumar
# 520	+91 99860 38804
# 475	+91 89288 60704
# 27	Sonu Sihmar
# 1456	Akshay N S
# 112	Shiva K
# 381	Archit Gupta
# 1001	Abhishek Samuel
# 30570	Divjot Singh
# 166	+91 98402 45280
# 3930	Prishkrit Abrol
# 184	+91 79046 73342
# 160	+91 97654 94035
# 267	+91 94497 21155
# 473	+91 90486 89898
# 2044	Shambhavi Choudhary
# 305	Ashutosh Bits Leisure
# 74	+91 98185 24648
# 364	+91 81059 07242
# 232	+91 98409 10527
# 532	+91 93227 10793
# 121	+65 9720 6217
# 414	+91 94454 54528
# 101	+1 (602) 651-8940
# 35	+91 98873 98089
# 289	+91 97399 01577
# 100	+971 50 633 0314
# 769	Mayank Kumar
# 4504	Sharath Krishnan Bits
# 51	Prat Bits
# 1084	Abhishek Samuel Bits
# 2012	Akshay N S Bits
# 1940	Dominic Gerard Bits
# 286	Sonu Sihmar Bits
# 3813	Shashi Kumar Srivastav Bits
# 166	+91 88613 50346
# 462	Rahul Singh Bits
# 119	Shiva K Bits
# 144	Abhijit Daund Bits
# 107	+91 95608 45500
# ()
# #########################
# ##  Messages per hour  ##
# #########################
# ()
# Shashi Kumar Srivastav:	0
# Rahul Singh:	0
# +91 98108 97330:	0
# Dominic Gerard:	0
# Abdul Ahad:	0
# +91 81350 57013:	0
# Ashish Jain:	0
# +91 94192 45911:	0
# +91 95607 86617:	0
# +91 91644 72637:	0
# +91 90947 22757:	0
# +91 87905 60139:	0
# Vivek Chaudhary:	0
# +91 97767 79025:	0
# +91 78771 56879:	0
# +91 91764 00158:	0
# +91 98453 79325:	0
# +91 96001 36104:	0
# Salil Bansal:	0
# +91 97625 07666:	0
# +91 98905 33682:	0
# +91 95452 79257:	0
# +91 77608 58999:	0
# Sharath Krishnan:	0
# Harmesh Rekhanshu:	0
# +91 95003 10376:	0
# Mayank S Kumar:	0
# +91 99860 38804:	0
# +91 89288 60704:	0
# Sonu Sihmar:	0
# Akshay N S:	0
# Shiva K:	0
# Archit Gupta:	0
# Abhishek Samuel:	0
# Divjot Singh:	1
# +91 98402 45280:	0
# Prishkrit Abrol:	0
# +91 79046 73342:	0
# +91 97654 94035:	0
# +91 94497 21155:	0
# +91 90486 89898:	0
# Shambhavi Choudhary:	0
# Ashutosh Bits Leisure:	0
# +91 98185 24648:	0
# +91 81059 07242:	0
# +91 98409 10527:	0
# +91 93227 10793:	0
# +65 9720 6217:	0
# +91 94454 54528:	0
# +1 (602) 651-8940:	0
# +91 98873 98089:	0
# +91 97399 01577:	0
# +971 50 633 0314:	0
# Mayank Kumar:	0
# Sharath Krishnan Bits:	0
# Prat Bits:	0
# Abhishek Samuel Bits:	0
# Akshay N S Bits:	0
# Dominic Gerard Bits:	0
# Sonu Sihmar Bits:	0
# Shashi Kumar Srivastav Bits:	0
# +91 88613 50346:	0
# Rahul Singh Bits:	0
# Shiva K Bits:	0
# Abhijit Daund Bits:	0
# +91 95608 45500:	0
# ()
# ################################
# ##  Avg nr Words per Message  ##
# ################################
# ()
# Shashi Kumar Srivastav: 13.0
# Rahul Singh: 7.0
# +91 98108 97330: 4.0
# Dominic Gerard: 15.0
# Abdul Ahad: 17.0
# +91 81350 57013: 11.0
# Ashish Jain: 6.0
# +91 94192 45911: 6.0
# +91 95607 86617: 3.0
# +91 91644 72637: 9.0
# +91 90947 22757: 4.0
# +91 87905 60139: 4.0
# Vivek Chaudhary: 11.0
# +91 97767 79025: 10.0
# +91 78771 56879: 10.0
# +91 91764 00158: 19.0
# +91 98453 79325: 5.0
# +91 96001 36104: 5.0
# Salil Bansal: 15.0
# +91 97625 07666: 5.0
# +91 94215 80968: 3.0
# +91 98905 33682: 8.0
# +91 95452 79257: 13.0
# +91 77608 58999: 7.0
# Sharath Krishnan: 8.0
# Harmesh Rekhanshu: 6.0
# +91 95003 10376: 7.0
# Mayank S Kumar: 11.0
# +91 99860 38804: 11.0
# +91 89288 60704: 12.0
# Sonu Sihmar: 3.0
# Akshay N S: 14.0
# Shiva K: 14.0
# Archit Gupta: 10.0
# Abhishek Samuel: 16.0
# Divjot Singh: 11.0
# +91 98402 45280: 8.0
# Prishkrit Abrol: 9.0
# +91 79046 73342: 12.0
# +91 97654 94035: 7.0
# +91 94497 21155: 17.0
# +91 90486 89898: 11.0
# Shambhavi Choudhary: 11.0
# Ashutosh Bits Leisure: 12.0
# +91 98185 24648: 4.0
# +91 81059 07242: 12.0
# +91 98409 10527: 11.0
# +91 93227 10793: 6.0
# +65 9720 6217: 5.0
# +91 94454 54528: 18.0
# +1 (602) 651-8940: 10.0
# +91 98873 98089: 3.0
# +91 97399 01577: 5.0
# +971 50 633 0314: 9.0
# Mayank Kumar: 5.0
# Sharath Krishnan Bits: 9.0
# Prat Bits: 7.0
# Abhishek Samuel Bits: 11.0
# Akshay N S Bits: 12.0
# Dominic Gerard Bits: 13.0
# Sonu Sihmar Bits: 9.0
# Shashi Kumar Srivastav Bits: 15.0
# +91 88613 50346: 11.0
# Rahul Singh Bits: 7.0
# Shiva K Bits: 7.0
# Abhijit Daund Bits: 11.0
# +91 95608 45500: 8.0
# ()
# #############################
# ##  Avg length of Message  ##
# #############################
# ()
# Shashi Kumar Srivastav: 74.0
# Rahul Singh: 44.0
# +91 98108 97330: 58.0
# Dominic Gerard: 95.0
# Abdul Ahad: 107.0
# +91 81350 57013: 62.0
# Ashish Jain: 50.0
# +91 94192 45911: 40.0
# +91 95607 86617: 12.0
# +91 91644 72637: 57.0
# +91 90947 22757: 23.0
# +91 87905 60139: 22.0
# Vivek Chaudhary: 63.0
# +91 97767 79025: 57.0
# +91 78771 56879: 53.0
# +91 91764 00158: 106.0
# +91 98453 79325: 28.0
# +91 96001 36104: 23.0
# Salil Bansal: 77.0
# +91 97625 07666: 29.0
# +91 94215 80968: 15.0
# +91 98905 33682: 51.0
# +91 95452 79257: 74.0
# +91 77608 58999: 40.0
# Sharath Krishnan: 54.0
# Harmesh Rekhanshu: 29.0
# +91 95003 10376: 41.0
# Mayank S Kumar: 66.0
# +91 99860 38804: 62.0
# +91 89288 60704: 71.0
# Sonu Sihmar: 18.0
# Akshay N S: 73.0
# Shiva K: 77.0
# Archit Gupta: 54.0
# Abhishek Samuel: 94.0
# Divjot Singh: 74.0
# +91 98402 45280: 41.0
# Prishkrit Abrol: 50.0
# +91 79046 73342: 67.0
# +91 97654 94035: 44.0
# +91 94497 21155: 88.0
# +91 90486 89898: 68.0
# Shambhavi Choudhary: 63.0
# Ashutosh Bits Leisure: 62.0
# +91 98185 24648: 33.0
# +91 81059 07242: 74.0
# +91 98409 10527: 61.0
# +91 93227 10793: 46.0
# +65 9720 6217: 30.0
# +91 94454 54528: 105.0
# +1 (602) 651-8940: 70.0
# +91 98873 98089: 45.0
# +91 97399 01577: 30.0
# +971 50 633 0314: 46.0
# Mayank Kumar: 49.0
# Sharath Krishnan Bits: 60.0
# Prat Bits: 37.0
# Abhishek Samuel Bits: 71.0
# Akshay N S Bits: 68.0
# Dominic Gerard Bits: 75.0
# Sonu Sihmar Bits: 54.0
# Shashi Kumar Srivastav Bits: 83.0
# +91 88613 50346: 64.0
# Rahul Singh Bits: 39.0
# Shiva K Bits: 69.0
# Abhijit Daund Bits: 54.0
# +91 95608 45500: 59.0
# ()
# ##############################
# ##  Highscore Day per User  ##
# ##############################
# ()
# Shashi Kumar Srivastav
# Messages: 	33
# Day: 		2020-01-04
# ()
# Rahul Singh
# Messages: 	6
# Day: 		2019-07-15
# ()
# +91 98108 97330
# Messages: 	8
# Day: 		2019-07-15
# ()
# Dominic Gerard
# Messages: 	35
# Day: 		2019-12-24
# ()
# Abdul Ahad
# Messages: 	9
# Day: 		2020-02-11
# ()
# +91 81350 57013
# Messages: 	29
# Day: 		2020-01-16
# ()
# Ashish Jain
# Messages: 	15
# Day: 		2020-01-22
# ()
# +91 94192 45911
# Messages: 	2
# Day: 		2019-12-21
# ()
# +91 95607 86617
# Messages: 	4
# Day: 		2020-03-12
# ()
# +91 91644 72637
# Messages: 	8
# Day: 		2019-07-15
# ()
# +91 90947 22757
# Messages: 	3
# Day: 		2020-01-05
# ()
# +91 87905 60139
# Messages: 	22
# Day: 		2019-07-14
# ()
# Vivek Chaudhary
# Messages: 	14
# Day: 		2020-02-24
# ()
# +91 97767 79025
# Messages: 	62
# Day: 		2020-02-25
# ()
# +91 78771 56879
# Messages: 	13
# Day: 		2019-07-15
# ()
# +91 91764 00158
# Messages: 	12
# Day: 		2020-02-16
# ()
# +91 98453 79325
# Messages: 	3
# Day: 		2020-01-21
# ()
# +91 96001 36104
# Messages: 	8
# Day: 		2019-07-14
# ()
# Salil Bansal
# Messages: 	112
# Day: 		2020-02-11
# ()
# +91 97625 07666
# Messages: 	12
# Day: 		2020-03-10
# ()
# +91 94215 80968
# Messages: 	13
# Day: 		2019-07-14
# ()
# +91 98905 33682
# Messages: 	8
# Day: 		2020-02-21
# ()
# +91 95452 79257
# Messages: 	2
# Day: 		2020-03-09
# ()
# +91 77608 58999
# Messages: 	8
# Day: 		2020-01-21
# ()
# Sharath Krishnan
# Messages: 	114
# Day: 		2019-12-24
# ()
# Harmesh Rekhanshu
# Messages: 	35
# Day: 		2019-12-24
# ()
# +91 95003 10376
# Messages: 	15
# Day: 		2019-12-22
# ()
# Mayank S Kumar
# Messages: 	55
# Day: 		2019-12-20
# ()
# +91 99860 38804
# Messages: 	7
# Day: 		2020-02-27
# ()
# +91 89288 60704
# Messages: 	21
# Day: 		2020-02-27
# ()
# Sonu Sihmar
# Messages: 	3
# Day: 		2019-12-21
# ()
# Akshay N S
# Messages: 	17
# Day: 		2020-01-07
# ()
# Shiva K
# Messages: 	5
# Day: 		2020-01-07
# ()
# Archit Gupta
# Messages: 	13
# Day: 		2020-02-08
# ()
# Abhishek Samuel
# Messages: 	8
# Day: 		2020-01-08
# ()
# Divjot Singh
# Messages: 	155
# Day: 		2019-12-24
# ()
# +91 98402 45280
# Messages: 	3
# Day: 		2020-02-14
# ()
# Prishkrit Abrol
# Messages: 	46
# Day: 		2020-02-11
# ()
# +91 79046 73342
# Messages: 	13
# Day: 		2019-12-20
# ()
# +91 97654 94035
# Messages: 	4
# Day: 		2020-01-16
# ()
# +91 94497 21155
# Messages: 	6
# Day: 		2020-02-11
# ()
# +91 90486 89898
# Messages: 	5
# Day: 		2020-01-11
# ()
# Shambhavi Choudhary
# Messages: 	17
# Day: 		2020-01-16
# ()
# Ashutosh Bits Leisure
# Messages: 	6
# Day: 		2020-03-07
# ()
# +91 98185 24648
# Messages: 	4
# Day: 		2020-01-06
# ()
# +91 81059 07242
# Messages: 	10
# Day: 		2020-02-05
# ()
# +91 98409 10527
# Messages: 	7
# Day: 		2020-01-04
# ()
# +91 93227 10793
# Messages: 	8
# Day: 		2020-01-05
# ()
# +65 9720 6217
# Messages: 	4
# Day: 		2020-03-10
# ()
# +91 94454 54528
# Messages: 	8
# Day: 		2019-12-26
# ()
# +1 (602) 651-8940
# Messages: 	5
# Day: 		2020-03-11
# ()
# +91 98873 98089
# Messages: 	2
# Day: 		2019-12-27
# ()
# +91 97399 01577
# Messages: 	7
# Day: 		2020-01-25
# ()
# +971 50 633 0314
# Messages: 	2
# Day: 		2020-01-06
# ()
# Mayank Kumar
# Messages: 	11
# Day: 		2020-01-17
# ()
# Sharath Krishnan Bits
# Messages: 	54
# Day: 		2020-02-27
# ()
# Prat Bits
# Messages: 	3
# Day: 		2020-02-12
# ()
# Abhishek Samuel Bits
# Messages: 	9
# Day: 		2020-02-25
# ()
# Akshay N S Bits
# Messages: 	24
# Day: 		2020-01-25
# ()
# Dominic Gerard Bits
# Messages: 	24
# Day: 		2020-01-17
# ()
# Sonu Sihmar Bits
# Messages: 	7
# Day: 		2020-01-23
# ()
# Shashi Kumar Srivastav Bits
# Messages: 	25
# Day: 		2020-02-22
# ()
# +91 88613 50346
# Messages: 	6
# Day: 		2020-02-01
# ()
# Rahul Singh Bits
# Messages: 	12
# Day: 		2020-02-08
# ()
# Shiva K Bits
# Messages: 	6
# Day: 		2020-02-01
# ()
# Abhijit Daund Bits
# Messages: 	8
# Day: 		2020-02-01
# ()
# +91 95608 45500
# Messages: 	9
# Day: 		2020-03-06
# ()
# ########################################
# ##  How often user said "I love you"  ##
# ########################################
# ()
# Shashi Kumar Srivastav:       0
# Rahul Singh:                  0
# +91 98108 97330:              0
# Dominic Gerard:               0
# Abdul Ahad:                   1
# +91 81350 57013:              0
# Ashish Jain:                  0
# +91 94192 45911:              0
# +91 95607 86617:              0
# +91 91644 72637:              0
# +91 90947 22757:              0
# +91 87905 60139:              0
# Vivek Chaudhary:              1
# +91 97767 79025:              0
# +91 78771 56879:              0
# +91 91764 00158:              0
# +91 98453 79325:              0
# +91 96001 36104:              0
# Salil Bansal:                 0
# +91 97625 07666:              0
# +91 94215 80968:              0
# +91 98905 33682:              0
# +91 95452 79257:              0
# +91 77608 58999:              0
# Sharath Krishnan:             0
# Harmesh Rekhanshu:            0
# +91 95003 10376:              0
# Mayank S Kumar:               0
# +91 99860 38804:              0
# +91 89288 60704:              0
# Sonu Sihmar:                  0
# Akshay N S:                   0
# Shiva K:                      0
# Archit Gupta:                 0
# Abhishek Samuel:              0
# Divjot Singh:                 0
# +91 98402 45280:              0
# Prishkrit Abrol:              0
# +91 79046 73342:              0
# +91 97654 94035:              0
# +91 94497 21155:              0
# +91 90486 89898:              0
# Shambhavi Choudhary:          0
# Ashutosh Bits Leisure:        0
# +91 98185 24648:              0
# +91 81059 07242:              0
# +91 98409 10527:              0
# +91 93227 10793:              0
# +65 9720 6217:                0
# +91 94454 54528:              0
# +1 (602) 651-8940:            0
# +91 98873 98089:              0
# +91 97399 01577:              0
# +971 50 633 0314:             0
# Mayank Kumar:                 0
# Sharath Krishnan Bits:        0
# Prat Bits:                    0
# Abhishek Samuel Bits:         0
# Akshay N S Bits:              0
# Dominic Gerard Bits:          0
# Sonu Sihmar Bits:             0
# Shashi Kumar Srivastav Bits:  0
# +91 88613 50346:              0
# Rahul Singh Bits:             0
# Shiva K Bits:                 0
# Abhijit Daund Bits:           0
# +91 95608 45500:              0

# %%
general.print_stats(df[df['User'] == "Shambhavi Choudhary"], love=True)
# NR / Nr / nr: implies "number"
# Out:
# ##########################
# ##  Number of Messages  ##
# ##########################
# ()
# 181	Shambhavi Choudhary
# ()
# #######################
# ##  Number of Words  ##
# #######################
# ()
# 2044	Shambhavi Choudhary
# ()
# #########################
# ##  Messages per hour  ##
# #########################
# ()
# Shambhavi Choudhary:	0
# ()
# ################################
# ##  Avg nr Words per Message  ##
# ################################
# ()
# Shambhavi Choudhary: 11.0
# ()
# #############################
# ##  Avg length of Message  ##
# #############################
# ()
# Shambhavi Choudhary: 63.0
# ()
# ##############################
# ##  Highscore Day per User  ##
# ##############################
# ()
# soan_master\whatsapp\general.py:429: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['avg_length_words'] = df.apply(lambda row: len(row.Message_Only_Text.split(" ")), 1)
# soan_master\whatsapp\general.py:430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['avg_length_charac'] = df.apply(lambda row: len(row.Message_Only_Text), 1)
# soan_master\whatsapp\general.py:450: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['Date_only'] = df.apply(lambda x: str(x.Date).split(' ')[0], 1)
# Shambhavi Choudhary
# Messages: 	17
# Day: 		2020-01-16
# ()
# ########################################
# ##  How often user said "I love you"  ##
# ########################################
# ()
# Shambhavi Choudhary:          0
# soan_master\whatsapp\general.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['Love'] = df.apply(lambda row: get_words_love(row), axis=1)

# %% [markdown]
# #### <a name="gs-response">2.6 Response Time</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# **keep_order = True** maintains the order of messages in the dataframe which is neccesary in order to calculate the response time between messages. However, it is more time-consuming which is why I created a separate function for this.

# %%
# df.sort_values('Date', inplace=True)
general.print_timing(df)
# Out:
# #####################################
# ##  Avg. Response Time in Minutes  ##
# #####################################
# ()
# +91 98108 97330:              80.3
# Abdul Ahad:                   34.77
# Ashish Jain:                  29.43
# +91 94192 45911:              20.36
# +91 91644 72637:              53.55
# Vivek Chaudhary:              25.72
# +91 81350 57013:              20.71
# +91 97767 79025:              27.87
# +91 78771 56879:              10.86
# +91 91764 00158:              33.33
# +91 98453 79325:              44.44
# +91 87905 60139:              21.81
# +91 96001 36104:              12.63
# Salil Bansal:                 9.3
# Rahul Singh:                  59.65
# Shashi Kumar Srivastav:       31.72
# +91 97625 07666:              23.2
# +91 90947 22757:              13.78
# +91 94215 80968:              2.33
# +91 98905 33682:              69.18
# +91 95452 79257:              119.08
# +91 77608 58999:              13.92
# Sharath Krishnan:             5.98
# Harmesh Rekhanshu:            6.88
# +91 95003 10376:              46.42
# Mayank S Kumar:               17.92
# +91 99860 38804:              9.72
# +91 89288 60704:              6.23
# Sonu Sihmar:                  96.0
# Akshay N S:                   25.72
# Dominic Gerard:               22.55
# Shiva K:                      12.0
# Archit Gupta:                 23.38
# Abhishek Samuel:              19.12
# Divjot Singh:                 10.37
# +91 98402 45280:              35.33
# Prishkrit Abrol:              3.72
# +91 79046 73342:              3.14
# +91 97654 94035:              45.89
# +91 94497 21155:              6.21
# +91 90486 89898:              67.13
# Shambhavi Choudhary:          12.71
# Ashutosh Bits Leisure:        10.14
# +91 98185 24648:              42.38
# +91 81059 07242:              24.27
# +91 95607 86617:              76.58
# +91 98409 10527:              46.93
# +91 93227 10793:              39.42
# +65 9720 6217:                45.89
# +91 94454 54528:              18.47
# +1 (602) 651-8940:            0.44
# +91 98873 98089:              61.6
# +91 97399 01577:              19.32
# +971 50 633 0314:             13.13
# Mayank Kumar:                 20.77
# Sharath Krishnan Bits:        11.95
# Prat Bits:                    12.29
# Abhishek Samuel Bits:         16.8
# Akshay N S Bits:              11.51
# Dominic Gerard Bits:          32.44
# Sonu Sihmar Bits:             66.0
# Shashi Kumar Srivastav Bits:  30.26
# +91 88613 50346:              1.92
# Rahul Singh Bits:             56.19
# Shiva K Bits:                 21.19
# Abhijit Daund Bits:           1.3
# +91 95608 45500:              13.22
# ()
# ##############################
# ##  Nr. Initiated Messages  ##
# ##############################
# ()
# Rahul Singh:                  2		(0.0%  of all messages)
# Dominic Gerard:               2		(0.0%  of all messages)
# Abdul Ahad:                   1		(0.0%  of all messages)
# +91 81350 57013:              2		(0.0%  of all messages)
# Ashish Jain:                  1		(0.0%  of all messages)
# +91 95607 86617:              1		(0.0%  of all messages)
# Shashi Kumar Srivastav:       1		(0.0%  of all messages)
# +91 90947 22757:              1		(0.0%  of all messages)
# +91 87905 60139:              1		(0.0%  of all messages)
# Sharath Krishnan:             1		(0.0%  of all messages)

# %% [markdown]
# ## <a name="tfidf">3. TF-IDF</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# #### <a name="tf-count">3.1 Create Count Vector</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# It creates the dataframe "counts" which is a dataframe that contains each word that is said in all conversations and counts how often each user has said that word.

# %%
counts = tf_idf.count_words_per_user(df[df["User"] == "Shambhavi Choudhary"],sentence_column="Message_Only_Text", user_column="User")
counts = tf_idf.remove_stopwords(counts, column="Word")

# %% [markdown]
# #### <a name="tf-unique">3.2 Unique Words</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# Below you can see three version of TF-IDF that I created. After much experimentation it turns out that they are all quite similar and that Version C gives me a nice distribution of values needed for the plotting. Content-wise they all have a very similar meaning.
#
# **Version A - Messages**
#
# $TFIDF_i = \frac{{t_{ij}+1}^2}{\sum_{i=1}^{n} t_j} \times \frac{\sum_{i=1}^{n} m_i}{m_i} $
#
# $t_{ij} = $ Number of times word $j$ said by $i$
# $m_i = $ Number of messages texted by $i$
#
#
# **Version B - Words**
#
# $TFIDF_i = \frac{{t_{ij}+1}^2}{\sum_{i=1}^{n} t_j} \times \frac{\sum_{i=1}^{n} w_i}{w_i}$
#
# $t_{ij} = $ Number of times a specific word $j$ was said by $i$
# $w_i = $ Number of words texted by $i$
#
#
# **Version C - Adjusted TF-IDF**
#
# $ TFIDF_i = \frac{{t_{ij} + 1}}{w_i + 1} \times \log{\frac{m}{\sum_{i=1}^{n} t_j}} $
# $w_i = $ Number of words texted by $i$
# $t_{ij} = $ Number of times a specific word $j$ was said by $i$
# $m = $ Number of all messages
#
# ** Unique Words **
#
# $ Unique_i = \frac{TFIDF_i}{\sum\limits_{j, j \neq i}^n TFIDF_i} $

# %%
unique_words = tf_idf.get_unique_words(counts, df[df["User"] == "Shambhavi Choudhary"], version = 'C')

# %% [markdown]
# #### <a name="tf-image">3.3 Plot Image</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# This is where things got a bit tricky...
#
# I created a horizontal bar chart with two bars stacked on top of each other both plotted on a background image. I started with a background image and plotted the actual values on the left and made it fully transparent with a white border to separate the bars. Then, on top of that I plotted which bars so that the right part of the image would get removed.

# %%
tf_idf.print_users(df)
# Out:
# #############
# ##  Users  ##
# #############
# ()
# Shashi Kumar Srivastav
# Rahul Singh
# +91 98108 97330
# Dominic Gerard
# Abdul Ahad
# +91 81350 57013
# Ashish Jain
# +91 94192 45911
# +91 95607 86617
# +91 91644 72637
# +91 90947 22757
# +91 87905 60139
# Vivek Chaudhary
# +91 97767 79025
# +91 78771 56879
# +91 91764 00158
# +91 98453 79325
# +91 96001 36104
# Salil Bansal
# +91 97625 07666
# +91 94215 80968
# +91 98905 33682
# +91 95452 79257
# +91 77608 58999
# Sharath Krishnan
# Harmesh Rekhanshu
# +91 95003 10376
# Mayank S Kumar
# +91 99860 38804
# +91 89288 60704
# Sonu Sihmar
# Akshay N S
# Shiva K
# Archit Gupta
# Abhishek Samuel
# Divjot Singh
# +91 98402 45280
# Prishkrit Abrol
# +91 79046 73342
# +91 97654 94035
# +91 94497 21155
# +91 90486 89898
# Shambhavi Choudhary
# Ashutosh Bits Leisure
# +91 98185 24648
# +91 81059 07242
# +91 98409 10527
# +91 93227 10793
# +65 9720 6217
# +91 94454 54528
# +1 (602) 651-8940
# +91 98873 98089
# +91 97399 01577
# +971 50 633 0314
# Mayank Kumar
# Sharath Krishnan Bits
# Prat Bits
# Abhishek Samuel Bits
# Akshay N S Bits
# Dominic Gerard Bits
# Sonu Sihmar Bits
# Shashi Kumar Srivastav Bits
# +91 88613 50346
# Rahul Singh Bits
# Shiva K Bits
# Abhijit Daund Bits
# +91 95608 45500

# %% [markdown]
# **Instructions**
# Make sure to change "user" in the function below to one of the users as seen above. It needs to be the exact same naming otherwise it will not work. Furthermore, a valid picture needs to be selected. You can choose the sizing yourself which might need some experimenting with before finding the right size. It also works with a link to the image online.

# %% [raw]
# for username in set(df.User.values):
#     tf_idf.plot_unique_words(unique_words, user = username, image_path='histogram.jpg', image_url=None,
#                              title = username, title_color="white",
#                              title_background='#AAAAAA', width=400, height=500)

# %%
tf_idf.plot_unique_words(unique_words, user = "Shambhavi Choudhary", image_path='histogram.jpg', image_url=None, 
                         title = "Shambhavi Choudhary", title_color="white", 
                         title_background='#AAAAAA', width=400, height=500)

# %% [markdown]
# ## <a name="emoji">4. Emoji Analysis</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# These analysis are based on the Emojis used in each message. Below you can find the following:
# * Unique Emoji per user
# * Commonly used Emoji per user
# * Highly correlated Emoji per user

# %% [markdown]
# #### <a name="emoji-prepare">4.1 Prepare Data</a>
# [Back to Table of Contents](#table)
#
# The data needs to be prepared as follows:
# * Three new columns are created:
#     * *Emoji* contains all emojis in a message
#     * *Emoji_Counts* counts the number of emojis in a message
#     * *Different_Emojis* extracts them in a list for handling purposes
# * *counts* is a dictionary of dictionaries containing the count of each emoji per user
# * *unique_emoji* is a dict of dicts containing a uniqueness score of each emoji per user compared to other users

# %%
# https://github.com/pandas-dev/pandas/issues/17892
temp = df[['index', 'Message_Raw', 'User', 'Message_Clean', 'Message_Only_Text']].copy()
temp = soan_emoji.prepare_data(temp)

# Count all emojis
counts = soan_emoji.count_emojis(temp, non_unicode=True)

# Get unique emojis
list_of_words = [word for user in counts for word in counts[user]]
unique_emoji = soan_emoji.get_unique_emojis(temp, counts, list_of_words)
del temp
# Out:
# soan_master\whatsapp\soan_emoji.py:139: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   return ''.join(c for c in str if c in emoji_package.UNICODE_EMOJI)
# soan_master\whatsapp\soan_emoji.py:131: RuntimeWarning: invalid value encountered in double_scalars
#   unique_dict[user][word] = tf_idf_user / (tf_idf_all - tf_idf_user)

# %% [markdown]
# #### <a name="emoji-stats">4.2 Unique and Common Emoji</a>
# [Back to Table of Contents](#table)
#
# Below you can find the most unique emojis according to the TF-IDF and Unique formulas that were used previously:
#
# ** TF-IDF **
#
# $ TFIDF_i = \frac{{t_{ij} + 1}}{w_i + 1} \times \log{\frac{m}{\sum_{i=1}^{n} t_j}} $
# $w_i = $ Number of words texted by $i$
# $t_{ij} = $ Number of times a specific emoji $j$ was said by $i$
# $m = $ Number of all messages
#
# ** Unique Emoji **
#
# $ Unique_i = \frac{TFIDF_i}{\sum\limits_{j, j \neq i}^n TFIDF_i} $
#
# I purposefully based it on the number of words and messages in total and only changed *t* to the number of times emoji was said

# %%
soan_emoji.print_stats(unique_emoji, counts)
# Out:
# #############################
# ### Unique Emoji (TF-IDF) ###
# #############################
# ()
# +91 96001 36104
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Sonu Sihmar Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 94497 21155
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98409 10527
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Abdul Ahad
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 91644 72637
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Sharath Krishnan Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98873 98089
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Vivek Chaudhary
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Shashi Kumar Srivastav Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +1 (602) 651-8940
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98905 33682
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 95452 79257
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98185 24648
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 81350 57013
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Divjot Singh
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 88613 50346
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Shashi Kumar Srivastav
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 89288 60704
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 97399 01577
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +65 9720 6217
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Shambhavi Choudhary
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Dominic Gerard Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 90486 89898
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Sharath Krishnan
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Prat Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Mayank S Kumar
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98402 45280
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 90947 22757
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Rahul Singh Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 97767 79025
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 94215 80968
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +971 50 633 0314
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 95003 10376
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Ashish Jain
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Akshay N S Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Abhishek Samuel Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 94192 45911
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 97654 94035
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Shiva K Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Akshay N S
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 95608 45500
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 87905 60139
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Salil Bansal
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Ashutosh Bits Leisure
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 79046 73342
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98108 97330
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Abhishek Samuel
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Archit Gupta
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 78771 56879
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 91764 00158
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Abhijit Daund Bits
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 95607 86617
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 98453 79325
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Mayank Kumar
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 81059 07242
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Dominic Gerard
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Prishkrit Abrol
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 94454 54528
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 77608 58999
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 99860 38804
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 97625 07666
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# +91 93227 10793
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Harmesh Rekhanshu
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Shiva K
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Rahul Singh
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# Sonu Sihmar
# (':/', nan)
# (':(', nan)
# ('8/', nan)
# ()
# #########################
# ### Most Common Emoji ###
# #########################
# ()
# +91 96001 36104
# ()
# Sonu Sihmar Bits
# (':/', 2)
# ('8/', 1)
# ()
# +91 94497 21155
# ()
# +91 98409 10527
# ()
# Abdul Ahad
# (':/', 24)
# (':)', 4)
# (':(', 1)
# ()
# +91 91644 72637
# (':/', 4)
# ()
# Sharath Krishnan Bits
# (':/', 55)
# ()
# +91 98873 98089
# (':/', 3)
# ()
# Vivek Chaudhary
# (':/', 3)
# ()
# Shashi Kumar Srivastav Bits
# (':/', 17)
# ('=D', 1)
# ()
# +1 (602) 651-8940
# (':/', 3)
# ()
# +91 98905 33682
# (':/', 2)
# ()
# +91 95452 79257
# (':/', 1)
# ()
# +91 98185 24648
# (':/', 5)
# ()
# +91 81350 57013
# (':/', 5)
# ('8/', 1)
# ('8D', 1)
# ()
# Divjot Singh
# (':/', 441)
# ('8/', 11)
# ('8P', 2)
# ()
# +91 88613 50346
# (':/', 2)
# ()
# Shashi Kumar Srivastav
# (':/', 12)
# ()
# +91 89288 60704
# (':/', 4)
# ()
# +91 97399 01577
# (':/', 1)
# ()
# +65 9720 6217
# (':/', 1)
# ()
# Shambhavi Choudhary
# (':/', 12)
# (':(', 1)
# ()
# Dominic Gerard Bits
# (':/', 12)
# (':(', 1)
# ()
# +91 90486 89898
# (':/', 8)
# ()
# Sharath Krishnan
# (':/', 70)
# ('8/', 3)
# ()
# Prat Bits
# ()
# Mayank S Kumar
# (':/', 44)
# ('8-p', 1)
# ('8/', 1)
# ()
# +91 98402 45280
# ()
# +91 90947 22757
# ()
# Rahul Singh Bits
# (':/', 5)
# ()
# +91 97767 79025
# (':/', 76)
# ('8/', 11)
# ('=p', 1)
# ()
# +91 94215 80968
# ()
# +971 50 633 0314
# ()
# +91 95003 10376
# (':/', 2)
# (':)', 1)
# ()
# Ashish Jain
# (':/', 21)
# ()
# Akshay N S Bits
# (':/', 3)
# ('BP', 1)
# ()
# Abhishek Samuel Bits
# (':/', 16)
# ('8/', 3)
# ('8D', 1)
# ()
# +91 94192 45911
# (':/', 1)
# ()
# +91 97654 94035
# (':/', 2)
# ()
# Shiva K Bits
# (':/', 6)
# ()
# Akshay N S
# (':/', 1)
# ()
# +91 95608 45500
# (':/', 3)
# ()
# +91 87905 60139
# (':/', 1)
# ()
# Salil Bansal
# (':/', 117)
# (':p', 5)
# ('BP', 3)
# ()
# Ashutosh Bits Leisure
# ()
# +91 79046 73342
# ()
# +91 98108 97330
# (':/', 6)
# ()
# Abhishek Samuel
# (':/', 7)
# ()
# Archit Gupta
# (":')", 1)
# (':/', 1)
# ()
# +91 78771 56879
# (':/', 6)
# ('8/', 1)
# ()
# +91 91764 00158
# (':/', 1)
# ('8/', 1)
# ()
# Abhijit Daund Bits
# (':/', 1)
# ()
# +91 95607 86617
# ()
# +91 98453 79325
# (':/', 2)
# ()
# Mayank Kumar
# (':/', 76)
# ('8/', 1)
# ()
# +91 81059 07242
# (':/', 5)
# ()
# Dominic Gerard
# (':/', 16)
# ('8D', 3)
# ()
# Prishkrit Abrol
# (':/', 6)
# ('BP', 1)
# ()
# +91 94454 54528
# (':/', 2)
# ()
# +91 77608 58999
# (':/', 1)
# ()
# +91 99860 38804
# (':/', 5)
# ()
# +91 97625 07666
# ()
# +91 93227 10793
# (':/', 18)
# ()
# Harmesh Rekhanshu
# (':/', 1)
# (':P', 1)
# ()
# Shiva K
# ()
# Rahul Singh
# (':/', 2)
# ()
# Sonu Sihmar
# (':/', 1)
# ()

# %% [raw]
# for username in set(df.User.values):
#     soan_emoji.plot_counts(counts, user = username)

# %% [markdown]
# #### <a name="emoji-corr">4.3 Correlation Matrix</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# Below you find a correlation matrix of the 15 most often used emoji by a single user. The reasoning for only taking 15 emojis is that otherwise the matrix simply becomes too big.

# %%
for username in set(df.User.values):
    soan_emoji.plot_corr_matrix(df, username, list_of_words, counts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-bb2cba73cf87> in <module>()
#       1 for username in set(df.User.values):
# ----> 2     soan_emoji.plot_corr_matrix(df, username, list_of_words, counts)
#
# D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp\soan_emoji.py in plot_corr_matrix(df, user, list_of_words, counts)
#     299     # Draw the heatmap with the mask and correct aspect ratio
#     300     sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
# --> 301                 square=True, linewidths=.5, cbar_kws={"shrink": .5})
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\seaborn\matrix.pyc in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\seaborn\matrix.pyc in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     165         # Determine good default values for the colormapping
#     166         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 167                                     cmap, center, robust)
#     168
#     169         # Sort out the annotations
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\seaborn\matrix.pyc in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     204         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     205         if vmin is None:
# --> 206             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#     207         if vmax is None:
#     208             vmax = np.percentile(calc_data, 98) if robust else calc_data.max()
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\numpy\core\_methods.pyc in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ## <a name="topic">5. Topic Modelling</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# #### <a name="topic-prepare">5.1 Prepare Data</a>
# [Back to Table of Contents](#table)
#
# The data is prepared as follows:
# The *pattern* is used as that is one of the few (sort of) working Dutch NLP-processors for python. There is generally little available with regards to Dutch processors. Since I want to extract topics translating text did not seem like the right way to go. So, using *pattern* I used the following functions where necessary:
# * Lemmatization
# * Singularize
# * Predicative
#
# Unfortunately, stemming was not an option since the Snowball stemmer from NLTK makes too many mistakes to be used.
#
# *NOTE*: These analyses are for the purpose of getting insights into whatsapp data. I did not spend much time optimizing algorithms for the simple reason that they already give good results out-of-the-box. Moreover, optimizing my results is likely not generalizable to your data as you are quick to overfit with such limited data.
#
# *NOTE2*: # Make sure to download the version for python 3+:
# * https://github.com/clips/pattern/tree/development
# * git clone -b development https://github.com/clips/pattern
# * cd pattern
# * python setup.py install

# %%
df['Message_Prepared'] = df.apply(lambda row: topic.prepare_text_nl(row), 1)

# %% [markdown]
# #### <a name="topic-lda">5.2 LDA </a>
# [Back to Table of Contents](#table)
#
# There is an abundance of methods with regards to topic modelling. Two, however, seem to be the most used: LDA and NMF. Sklearn has an implementation of both LDA and NMF which is why I used that. It should be noted that Gensim is also an extremely good package when it comes to NLP. I will be using Gensim later below for a different application.

# %%
topic.topics(df, model='lda', stopwords='stopwords_dutch.txt')
# Out:
# #######################
# ### +91 96741 64936 ###
# #######################
#
#
# Topics in lda model:
# Topic #0: hai lik say lagta me detention center
# Topic #1: me ne sir will no if kar
# Topic #2: hai ke ka kya liye ho itna
# Topic #3: zijn to and not in haaf nrc
# Topic #4: couren to will or be we who
# ()
# #######################################
# ### Rahul Singh Mobile App Dev Bits ###
# #######################################
#
#
# Topics in lda model:
# Topic #0: the zijn in of and ther dont
# Topic #1: to and jata ho ther the kar
# Topic #2: jata ho kar and this should to
# Topic #3: zijn this deleted message it eten look
# Topic #4: for lik but look in kar message
# ()
# #######################
# ### +91 98108 97330 ###
# #######################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-9d0f7b5910ac> in <module>()
# ----> 1 topic.topics(df, model='lda', stopwords='stopwords_dutch.txt')
#
# D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp\topic.py in topics(df, model, stopwords)
#     104             # Extracting Features
#     105             tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,stop_words=stopwords_list)
# --> 106             tf = tf_vectorizer.fit_transform(data_samples)
#     107
#     108             # Fitting LDA
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\sklearn\feature_extraction\text.pyc in fit_transform(self, raw_documents, y)
#    1050                                                        max_doc_count,
#    1051                                                        min_doc_count,
# -> 1052                                                        max_features)
#    1053
#    1054             self.vocabulary_ = vocabulary
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\sklearn\feature_extraction\text.pyc in _limit_features(self, X, vocabulary, high, low, limit)
#     919         kept_indices = np.where(mask)[0]
#     920         if len(kept_indices) == 0:
# --> 921             raise ValueError("After pruning, no terms remain. Try a lower"
#     922                              " min_df or a higher max_df.")
#     923         return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %% [markdown]
# #### <a name="topic-nmf">5.3 NMF </a>
# [Back to Table of Contents](#table)
#
# An application of the NMF model used for topic modelling.

# %%
topic.topics(df, model='nmf', stopwords='stopwords_dutch.txt')
# Out:
# #######################
# ### +91 96741 64936 ###
# #######################
#
#
# Topics in nmf model:
# Topic #0: zijn this new also in issue now
# Topic #1: hai yeh nahi me ka bhi aayega
# Topic #2: haaf you if all ar still doc
# Topic #3: not they ar country delhi them wer
# Topic #4: to and why in what nrc only
# ()
# #######################################
# ### Rahul Singh Mobile App Dev Bits ###
# #######################################
#
#
# Topics in nmf model:
# Topic #0: deleted message this zijn it but dont
# Topic #1: the in of dont zijn ther and
# Topic #2: look lik it but eten zijn should
# Topic #3: jata ho and kar the in but
# Topic #4: for to eten this zijn it but
# ()
# #######################
# ### +91 98108 97330 ###
# #######################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-5a805a40e30f> in <module>()
# ----> 1 topic.topics(df, model='nmf', stopwords='stopwords_dutch.txt')
#
# D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp\topic.py in topics(df, model, stopwords)
#     116             # MNF uses tfidf
#     117             tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words=stopwords_list)
# --> 118             tfidf = tfidf_vectorizer.fit_transform(data_samples)
#     119             feature_names = tfidf_vectorizer.get_feature_names()
#     120
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\sklearn\feature_extraction\text.pyc in fit_transform(self, raw_documents, y)
#    1611         """
#    1612         self._check_params()
# -> 1613         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1614         self._tfidf.fit(X)
#    1615         # X is already a transformed view of raw_documents so
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\sklearn\feature_extraction\text.pyc in fit_transform(self, raw_documents, y)
#    1050                                                        max_doc_count,
#    1051                                                        min_doc_count,
# -> 1052                                                        max_features)
#    1053
#    1054             self.vocabulary_ = vocabulary
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\sklearn\feature_extraction\text.pyc in _limit_features(self, X, vocabulary, high, low, limit)
#     919         kept_indices = np.where(mask)[0]
#     920         if len(kept_indices) == 0:
# --> 921             raise ValueError("After pruning, no terms remain. Try a lower"
#     922                              " min_df or a higher max_df.")
#     923         return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %% [markdown]
# ## <a name="sentiment">6. Sentiment</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# #### <a name="sentiment-prepare">6.1 Prepare Data</a>
# [Back to Table of Contents](#table)
#
# Fortunately, in order to extract sentiment from a Dutch message you can extract the score (-1 being negative and 1 being positive) easily using the pattern package. Below I extract the sentiment as a new column which is needed for further analysis.

# %%
from pattern.nl import sentiment  as sentiment_nl
df['Sentiment'] = df.apply(lambda row: sentiment_nl(row.Message_Clean)[0], 1)

# %% [markdown]
# #### <a name="sentiment-average">6.2 Average Sentiment Per User</a>
# [Back to Table of Contents](#table)
#
# Prints the average sentiment per user to get an indication of positivity of that user.
#
# *NOTE*: THIS ONLY WORKS FOR DUTCH!

# %%
sentiment.print_avg_sentiment(df)
# Out:
# 			#######################
# 			## Average Sentiment ##
# 			#######################
# +91 96741 64936:              		0.01
# Rahul Singh Mobile App Dev Bits:		0.11
# +91 98108 97330:              		0.096
# +91 95000 64740:              		0.01
# Abdul Ahad Bits Diss:         		0.135
# +91 81350 57013:              		0.035
# +91 94192 45911:              		0.233
# +91 91644 72637:              		0.11
# +91 90947 22757:              		0.444
# +91 87905 60139:              		0.12
# Vivek Chaudhary Bits Diss GrpC MAD:		-0.005
# +91 97767 79025:              		0.109
# +91 78771 56879:              		0.065
# +91 91764 00158:              		0.183
# +91 98453 79325:              		0.675
# +91 96001 36104:              		0.167
# Salil Bansal Diss Grp C Bits Infosys:		0.131
# +91 97625 07666:              		0.181
# +91 94215 80968:              		0.208
# +91 98905 33682:              		0.313
# +91 94804 94131:              		0.071
# Harmesh Kr Rekhanshu:         		0.057
# +91 95003 10376:              		0.019
# +91 99016 46061:              		0.044
# +91 89288 60704:              		0.05
# +91 99712 14555:              		0.125
# +91 98458 64865:              		0.04
# +91 99640 27359:              		0.113
# +91 96004 25452:              		0.311
# Divjot Singh Bits:            		0.037
# +91 99996 93486:              		0.1
# +91 79046 73342:              		0.0
# +91 97654 94035:              		0.4
# +91 90486 89898:              		0.181
# +91 80957 64285:              		0.047
# Ashutosh Bits Leisure:        		0.35
# +91 98409 10527:              		-0.015
# +91 93227 10793:              		0.135
# +91 94454 54528:              		0.243
# +91 98873 98089:              		0.143

# %% [markdown]
# #### <a name="sentiment-plot">6.3 Plot Sentiment</a>
# [Back to Table of Contents](#table)
#
# Below you can see a plot of how positive the messages are over time. The y-axis works as follows, a happy smiley indicates a score of 1 (max value) meaning a positive message and a sad smiley indicates a score of -1 (min value) meaning a negative message.

# %%
colors_list_2  = ['#EAAA69','#5361A5']
colors_list_8  = ['#EAAA69','#5361A5', '#000000', '#ff0000', '#00ff00', '#0000ff', '#ffff00', '#00ffff']

num_of_colors = len(set(df.User.values))
colors_list = []
for i in range(100000, num_of_colors):
    colors_list += ['#' + str(hex(i))[2:]]
    
sentiment.plot_sentiment(df, colors=colors_list, savefig=False)

# %% [markdown]
# ## <a name="cloud">7. Word Clouds</a>
# [Back to Table of Contents](#table)

# %% [markdown]
# #### <a name="cloud-prepare">7.1 Prepare Data</a>
# [Back to Table of Contents](#table)

# %%
# Counts words and create dictionary of words with counts
counts = tf_idf.count_words_per_user(df,sentence_column="Message_Only_Text",user_column="User")
counts = tf_idf.remove_stopwords(counts, column="Word")

# %% [markdown]
# #### <a name="cloud-mask">7.2 Masked Word Cloud</a>
# [Back to Table of Contents](#table)

# %%
soan_wordcloud.create_wordcloud(df.Message_Only_Text, # mask = 'mask.jpg', 
                           stopwords='stopwords_dutch.txt', random_state=42, 
                           max_words=1000, max_font_size=50, scale=2, 
                           normalize_plurals=False, relative_scaling = 0.5)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x400 at 0x2878E160>

# %% [markdown]
# #### <a name="cloud-sentiment">7.3 Sentiment-based Word Cloud</a>
# [Back to Table of Contents](#table)
#
# *NOTE*: ONLY WORKS FOR DUTCH

# %%
# Choose which user you want to see the word cloud for

for username in set(df.User.values):
    positive, negative = soan_wordcloud.extract_sentiment_count(counts, user = username)

# %% [markdown]
# ##### Positive Words

# %%
soan_wordcloud.create_wordcloud(data=positive, cmap='Greens', # mask='mask.jpg', 
                    stopwords='stopwords_dutch.txt', random_state=42, max_words=1000, 
                    max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.5)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300 at 0x2BCEB240>

# %% [markdown]
# ##### Negative Words

# %%
soan_wordcloud.create_wordcloud(data=negative, cmap='Reds', #mask='mask.jpg', 
                    stopwords='stopwords_dutch.txt', random_state=42, max_words=1000, 
                    max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-c11571158a81> in <module>()
#       1 soan_wordcloud.create_wordcloud(data=negative, cmap='Reds', #mask='mask.jpg',
#       2                     stopwords='stopwords_dutch.txt', random_state=42, max_words=1000,
# ----> 3                     max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.5)
#
# D:\workspace\Jupyter\exp_45.2_whatsapp\soan_master\whatsapp\soan_wordcloud.py in create_wordcloud(data, cmap, savefig, **kwargs)
#      54         wc.generate_from_text(text)
#      55     else:
# ---> 56         wc.generate_from_frequencies(data)
#      57
#      58     if not cmap:
#
# C:\Users\ashish.jain50\AppData\Local\Continuum\anaconda3\envs\py_2716\lib\site-packages\wordcloud\wordcloud.pyc in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# ## <a name="color">8. Picture Analysis</a>
# [Back to Table of Contents](#table)
#
# NOTE: This is not part of the whatsapp data. For this chapter to work, you'll need to put at least 1 image in the folder 'Images/' or create a path of your own. It is set to not run automatically since this is merely an extra feature. Set run_colors to True if you want to run the script.

# %% [markdown]
# #### <a name="color-get">8.1 Extract Frequent Colors (k-Means)</a>
# [Back to Table of Contents](#table)

# %%
import os
import pickle

# %% [markdown]
# Below is the code to retrieve and dump the top 5 most frequent colors in an image using k-Means.
# It works as follows, each pixel in an image has its own color. That color of each pixel in an image is then extracted in an rgb format. This allows each pixel to have an x (r), y (g) and z (b) coordinate. After extracting all colors of each pixel, k-Means (with k=5) is then used to cluster the points into 5 colors. For each cluster the mediod is calculated and used as a representative of that cluster. Thus, you get top 5 colors for each image.

# %%
extract_colors = False

if extract_colors:
    # Get Top 5 Frequent Colors
    path = 'Images/'
    all_colors = [colors.get_common_colors(path + i) for i in os.listdir(path)]

    # Save colors
    with open('colors.pkl', 'wb') as f:
        pickle.dump(all_colors, f)

# %% [markdown]
# #### <a name="color-plot">8.2 Plot Frequent Colors</a>
# [Back to Table of Contents](#table)
#
# After getting the top 5 colors for each picture, they are counted and then displayed below in a histogram. The histogram is in a circular shape where larger/bigger/higher bars indicate colors that are more frequent in the set of pictures. There is a version of the histogram that only shows bars and one that shows a smoothened histogram to be more visually pleasing.

# %%
colors.plot_color('colors.pkl', smoothen=False, savefig=False)

# %%
colors.plot_color('colors.pkl', smoothen=True, savefig=False)
