# %%
from sqlalchemy import create_engine
connection_string = "mysql+mysqlconnector://ash:password@localhost/leadsdb"
engine = create_engine(connection_string, echo=True)

# %%
# Gets price date and time from Unix timestamp that comes with the JSON response

import urllib.request

import json
from time import sleep, strftime
import logging
import datetime

def getBitcoinPrice():
    URL = 'https://www.bitstamp.net/api/ticker/'
    try:
        response = urllib.request.urlopen(URL)
        data = json.load(response)         
        priceFloat = float(data['last']) #Lastprice
        
        priceDate = datetime.datetime.fromtimestamp(int(data['timestamp'])).strftime('%d/%m/%Y')
        priceTime = datetime.datetime.fromtimestamp(int(data['timestamp'])).strftime('%H:%M:%S')

        return str(priceDate + "," + priceTime + "," + str(priceFloat))
    except Exception as e:
        print("Error querying Bitstamp API: ", e.reason)

# Output: 
# Date,Time,USD/BTC
# 06/01/2018,02:04:19,16384.75

# %%
with engine.connect() as connection:
    while True:
        t = str(getBitcoinPrice())
        t = t.split(",")
        connection.execute(
            """INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc) 
            VALUES ( '{0}', '{1}', '{2}' )""".format(
                t[0], t[1], t[2]
            )
        )

        sleep(10)
# Out:
# 2023-06-22 16:20:15,191 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:20:13', '30204.0' )
# 2023-06-22 16:20:15,191 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:20:15,193 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:20:25,554 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:20:24', '30206.0' )
# 2023-06-22 16:20:25,556 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:20:25,559 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:20:37,032 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:20:36', '30205.0' )
# 2023-06-22 16:20:37,033 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:20:37,034 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:21:06,294 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:20:57', '30205.0' )
# 2023-06-22 16:21:06,296 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:21:06,301 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:21:18,255 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:21:16', '30208.0' )
# 2023-06-22 16:21:18,257 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:21:18,261 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:21:31,365 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:21:28', '30207.0' )
# 2023-06-22 16:21:31,367 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:21:31,371 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:21:43,022 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:21:42', '30208.0' )
# 2023-06-22 16:21:43,024 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:21:43,028 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:21:56,210 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:21:53', '30208.0' )
# 2023-06-22 16:21:56,213 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:21:56,219 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:22:08,309 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:05', '30209.0' )
# 2023-06-22 16:22:08,310 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:22:08,312 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:22:18,710 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:16', '30209.0' )
# 2023-06-22 16:22:18,711 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:22:18,715 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:22:29,135 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:28', '30221.0' )
# 2023-06-22 16:22:29,136 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:22:29,137 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:22:39,865 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:38', '30223.0' )
# 2023-06-22 16:22:39,866 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:22:39,867 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:22:50,693 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:48', '30222.0' )
# 2023-06-22 16:22:50,694 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:22:50,696 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:01,304 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:22:59', '30221.0' )
# 2023-06-22 16:23:01,306 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:01,310 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:11,646 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:23:10', '30216.0' )
# 2023-06-22 16:23:11,646 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:11,648 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:22,340 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:23:19', '30218.0' )
# 2023-06-22 16:23:22,341 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:22,342 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:33,008 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:23:31', '30222.0' )
# 2023-06-22 16:23:33,010 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:33,014 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:43,698 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:23:42', '30223.0' )
# 2023-06-22 16:23:43,700 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:43,703 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:23:54,008 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:23:51', '30225.0' )
# 2023-06-22 16:23:54,009 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:23:54,010 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:24:04,364 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:02', '30225.0' )
# 2023-06-22 16:24:04,365 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:24:04,366 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:24:14,777 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:11', '30218.0' )
# 2023-06-22 16:24:14,779 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:24:14,783 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:24:25,462 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:24', '30207.0' )
# 2023-06-22 16:24:25,463 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:24:25,464 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:24:40,130 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:38', '30207.0' )
# 2023-06-22 16:24:40,132 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:24:40,138 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:24:50,789 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:48', '30207.0' )
# 2023-06-22 16:24:50,791 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:24:50,795 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:01,619 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:24:59', '30213.0' )
# 2023-06-22 16:25:01,622 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:01,626 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:12,072 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:25:10', '30214.0' )
# 2023-06-22 16:25:12,073 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:12,078 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:22,939 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:25:19', '30214.0' )
# 2023-06-22 16:25:22,941 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:22,946 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:33,494 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:25:32', '30214.0' )
# 2023-06-22 16:25:33,496 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:33,501 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:44,970 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:25:42', '30217.0' )
# 2023-06-22 16:25:44,972 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:44,976 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:25:55,557 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:25:54', '30214.0' )
# 2023-06-22 16:25:55,559 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:25:55,562 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:26:06,572 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:04', '30213.0' )
# 2023-06-22 16:26:06,574 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:26:06,578 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:26:17,509 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:16', '30212.0' )
# 2023-06-22 16:26:17,512 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:26:17,517 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:26:28,225 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:26', '30212.0' )
# 2023-06-22 16:26:28,228 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:26:28,231 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:26:38,723 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:36', '30212.0' )
# 2023-06-22 16:26:38,725 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:26:38,729 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:26:49,708 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:48', '30214.0' )
# 2023-06-22 16:26:49,709 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:26:49,710 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:27:00,812 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:26:58', '30213.0' )
# 2023-06-22 16:27:00,814 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:27:00,819 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:27:11,464 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:27:10', '30215.0' )
# 2023-06-22 16:27:11,466 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:27:11,470 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:27:21,939 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:27:21', '30216.0' )
# 2023-06-22 16:27:21,940 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:27:21,942 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:27:32,462 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:27:30', '30216.0' )
# 2023-06-22 16:27:32,465 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:27:32,470 INFO sqlalchemy.engine.base.Engine COMMIT
# 2023-06-22 16:27:43,314 INFO sqlalchemy.engine.base.Engine INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#             VALUES ( '22/06/2023', '16:27:41', '30216.0' )
# 2023-06-22 16:27:43,317 INFO sqlalchemy.engine.base.Engine {}
# 2023-06-22 16:27:43,320 INFO sqlalchemy.engine.base.Engine COMMIT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       4 t = t.split(",")
#       5 connection.execute(
#       6     """INSERT INTO bitcoinprice (ticker_date, ticker_time, usd_btc)
#       7     VALUES ( '{0}', '{1}', '{2}' )""".format(
#       8         t[0], t[1], t[2]
#       9     )
#      10 )
# ---> 12 sleep(10)
#
# KeyboardInterrupt:
