# %%
import pandas as pd
import dateutil

# %%
df = pd.read_csv('data/individual stocks/Quote-Equity-TATASTEEL-EQ-01-06-2022-to-01-06-2023.csv')

# %%
df['Date '] = df['Date '].apply(lambda x: dateutil.parser.parse(x))

# %%
df.sort_values(by="Date ", inplace = True)

# %%
df
# Out:
#          Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 248 2022-06-01      EQ  1,065.50  1,079.00  1,053.30     1,055.65  1,061.00
# 247 2022-06-02      EQ  1,067.75  1,084.75  1,059.10     1,063.55  1,081.00
# 246 2022-06-03      EQ  1,092.00  1,092.80  1,065.00     1,081.55  1,067.00
# 245 2022-06-06      EQ  1,065.00  1,082.90  1,049.20     1,067.30  1,079.00
# 244 2022-06-07      EQ  1,067.00  1,081.50  1,063.55     1,078.10  1,069.00
# ..         ...     ...       ...       ...       ...          ...       ...
# 4   2023-05-26      EQ    105.00    106.75    104.95       104.85    106.45
# 3   2023-05-29      EQ    107.00    108.85    106.30       106.40    108.35
# 2   2023-05-30      EQ    108.95    108.95    106.90       108.45    106.95
# 1   2023-05-31      EQ    106.40    106.95    105.60       107.05    105.85
# 0   2023-06-01      EQ    105.90    106.70    105.80       105.80    106.00
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(df['Date '], df['PREV. CLOSE '])
plt.show()
